# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from types import NoneType
# матрица весов
scores = np.genfromtxt('https://dc-edu.itmo.ru/assets/courseware/v1/77aa45fa03e88d5e9c64fee4ecc057ca/asset-v1:ITMO+bonus_track_methods+2023+type@asset+block/X_reduced_408.csv', delimiter=';')
# матрица счетов
loadings = np.genfromtxt('https://dc-edu.itmo.ru/assets/courseware/v1/5d215008da5cab9327940f16ad420057/asset-v1:ITMO+bonus_track_methods+2023+type@asset+block/X_loadings_408.csv', delimiter=';')

# %%
# матрица восстановленных данных
values = np.dot(scores,loadings.T)

# %%
plt.imshow(values, cmap='summer')
plt.show()
