# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('SPFB.RTS-12.18_180901_181231.csv')
df
# Out:
#              <TICKER>  <PER>    <DATE> <TIME>    <OPEN>    <HIGH>     <LOW>  \
# 0      SPFB.RTS-12.18      1  03/09/18  10:01  107900.0  108060.0  107900.0
# 1      SPFB.RTS-12.18      1  03/09/18  10:02  107960.0  107960.0  107960.0
# 2      SPFB.RTS-12.18      1  03/09/18  10:04  108000.0  108000.0  108000.0
# 3      SPFB.RTS-12.18      1  03/09/18  10:05  108000.0  108000.0  108000.0
# 4      SPFB.RTS-12.18      1  03/09/18  10:08  108080.0  108080.0  108080.0
# ...               ...    ...       ...    ...       ...       ...       ...
# 58965  SPFB.RTS-12.18      1  20/12/18  18:40  109380.0  109380.0  109380.0
# 58966  SPFB.RTS-12.18      1  20/12/18  18:41  109380.0  109390.0  109380.0
# 58967  SPFB.RTS-12.18      1  20/12/18  18:43  109380.0  109390.0  109380.0
# 58968  SPFB.RTS-12.18      1  20/12/18  18:44  109390.0  109390.0  109390.0
# 58969  SPFB.RTS-12.18      1  20/12/18  18:45  109390.0  109390.0  109380.0
#
#         <CLOSE>  <VOL>
# 0      108030.0      3
# ...

# %%
df['datetime'] = df['<DATE>'] + ' ' + df['<TIME>']
df.head()
# Out:
#          <TICKER>  <PER>    <DATE> <TIME>    <OPEN>    <HIGH>     <LOW>  \
# 0  SPFB.RTS-12.18      1  03/09/18  10:01  107900.0  108060.0  107900.0
# 1  SPFB.RTS-12.18      1  03/09/18  10:02  107960.0  107960.0  107960.0
# 2  SPFB.RTS-12.18      1  03/09/18  10:04  108000.0  108000.0  108000.0
# 3  SPFB.RTS-12.18      1  03/09/18  10:05  108000.0  108000.0  108000.0
# 4  SPFB.RTS-12.18      1  03/09/18  10:08  108080.0  108080.0  108080.0
#
#     <CLOSE>  <VOL>        datetime
# 0  108030.0      3  03/09/18 10:01
# 1  107960.0      5  03/09/18 10:02
# 2  108000.0      8  03/09/18 10:04
# 3  108000.0      1  03/09/18 10:05
# 4  108080.0      1  03/09/18 10:08

# %%
df['datetime'] = pd.to_datetime(df['datetime'], format='%d/%m/%y %H:%M')
df['datetime'].head()
# Out:
# 0   2018-09-03 10:01:00
# 1   2018-09-03 10:02:00
# 2   2018-09-03 10:04:00
# 3   2018-09-03 10:05:00
# 4   2018-09-03 10:08:00
# Name: datetime, dtype: datetime64[ns]

# %%
df_filtered = df[df['datetime'].dt.strftime('%Y-%m-%d') == '2018-09-28']
df_filtered = df_filtered.set_index('datetime')
df_filtered = df_filtered[['<OPEN>', '<HIGH>', '<LOW>', '<CLOSE>']]
df_filtered.columns =['open', 'high', 'low', 'close']
df_filtered.head()
# Out:
#                          open      high       low     close
# datetime
# 2018-09-28 10:01:00  116980.0  117260.0  116760.0  117160.0
# 2018-09-28 10:02:00  117150.0  117170.0  116850.0  116930.0
# 2018-09-28 10:03:00  116950.0  116960.0  116860.0  116930.0
# 2018-09-28 10:04:00  116920.0  116990.0  116880.0  116920.0
# 2018-09-28 10:05:00  116930.0  117010.0  116870.0  116950.0

# %%
to_plot = df_filtered.resample('1H').agg({'open':'first',
                                     'high':'max',
                                     'low':'min',
                                     'close':'last'})
to_plot
# Out:
#                          open      high       low     close
# datetime
# 2018-09-28 10:00:00  116980.0  117260.0  116300.0  116790.0
# 2018-09-28 11:00:00  116780.0  117530.0  116640.0  117510.0
# 2018-09-28 12:00:00  117510.0  117650.0  117010.0  117100.0
# 2018-09-28 13:00:00  117090.0  117240.0  116350.0  116860.0
# 2018-09-28 14:00:00  116860.0  117180.0  116510.0  116900.0
# 2018-09-28 15:00:00  116900.0  117270.0  116620.0  117210.0
# 2018-09-28 16:00:00  117210.0  117230.0  116540.0  116930.0
# 2018-09-28 17:00:00  116950.0  117880.0  116790.0  117830.0
# 2018-09-28 18:00:00  117840.0  118260.0  117720.0  118170.0
# 2018-09-28 19:00:00  118130.0  118350.0  117720.0  117970.0
# 2018-09-28 20:00:00  117980.0  118100.0  117840.0  117920.0
# 2018-09-28 21:00:00  117930.0  117980.0  117800.0  117820.0
# 2018-09-28 22:00:00  117810.0  117830.0  117430.0  117690.0
# 2018-09-28 23:00:00  117690.0  117900.0  117560.0  117680.0

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=to_plot.index,
                open=to_plot['open'],
                high=to_plot['high'],
                low=to_plot['low'],
                close=to_plot['close'])])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
